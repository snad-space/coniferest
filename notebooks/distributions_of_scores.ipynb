# %%
p = IsolationForest()

# %%
data = np.random.randn(10000, 5)
p.fit(data)
scores = (-p.score_samples(data)) ** average_path_length(p.n_subsamples)
plt.hist(scores, bins=20)
plt.title('normal data')
plt.yscale('log')

# %%
data = np.random.rand(10000, 5)
p.fit(data)
scores = (-p.score_samples(data)) ** average_path_length(p.n_subsamples)
plt.hist(scores, bins=20)
plt.title('uniform data')
plt.yscale('log')

# %%
data = np.random.exponential(scale=1, size=(100000, 5))
p.fit(data)
scores = (-p.score_samples(data)) ** average_path_length(p.n_subsamples)
plt.hist(scores, bins=20)
plt.title('exponent data')
plt.yscale('log')
